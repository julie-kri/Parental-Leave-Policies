# %%
import pandas as pd

# %%
a=pd.read_excel("/content/Parental leave policies.xlsx")

# %%
a.head()
# Out:
#                    Company                                   Industry  \
# 0                  Epsilon                                Advertising
# 1  The Walt Disney Company                       Arts & Entertainment
# 2          Guild Education                   Business Services: Other
# 3                   WeWork                   Business Services: Other
# 4             Randstad USA  Business Services: Staffing & Outsourcing
#
#    Paid Maternity Leave  Unpaid Maternity Leave  Paid Paternity Leave  \
# 0                   6.0                     6.0                   6.0
# 1                   5.0                     4.0                   4.5
# 2                  14.0                     0.0                   8.0
# 3                  14.0                     2.0                  16.0
# 4                   5.0                     7.0                   0.0
#
#    Unpaid Paternity Leave  Paid Parental Leave  Unpaid Parental Leave   \
# ...

# %%
a.shape
# Out:
# (1601, 12)

# %%
a.tail()
# Out:
#                         Company                             Industry  \
# 1596                       Xero                 Technology: Software
# 1597         Fedex Supply Chain  Transportation: Freight & Logistics
# 1598         Schneider National  Transportation: Freight & Logistics
# 1599                  HD Supply                            Wholesale
# 1600  Merrimac Industrial Sales                            Wholesale
#
#       Paid Maternity Leave  Unpaid Maternity Leave  Paid Paternity Leave  \
# 1596                   6.0                     0.0                   0.0
# 1597                   2.0                     0.0                   0.0
# 1598                   0.0                     0.0                   0.0
# 1599                  14.0                     0.0                   0.0
# 1600                   0.0                     0.0                   0.0
#
#       Unpaid Paternity Leave  Paid Parental Leave  Unpaid Parental Leave   \
# ...

# %%
a.count()
# Out:
# Company                   1601
# Industry                  1598
# Paid Maternity Leave      1601
# Unpaid Maternity Leave    1601
# Paid Paternity Leave      1601
# Unpaid Paternity Leave    1601
# Paid Parental Leave       1601
# Unpaid Parental Leave     1601
# Total Parental Leave      1601
# Total Maternity Leave     1601
# Total Paternity Leave     1601
# Maternity VS Paternity    1601
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=0, stop=1601, step=1)

# %%
a.describe
# Out:
# <bound method NDFrame.describe of                         Company                                   Industry  \
# 0                       Epsilon                                Advertising
# 1       The Walt Disney Company                       Arts & Entertainment
# 2               Guild Education                   Business Services: Other
# 3                        WeWork                   Business Services: Other
# 4                  Randstad USA  Business Services: Staffing & Outsourcing
# ...                         ...                                        ...
# 1596                       Xero                       Technology: Software
# 1597         Fedex Supply Chain        Transportation: Freight & Logistics
# 1598         Schneider National        Transportation: Freight & Logistics
# 1599                  HD Supply                                  Wholesale
# 1600  Merrimac Industrial Sales                                  Wholesale
#
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Company                 1601 non-null   object
#  1   Industry                1598 non-null   object
#  2   Paid Maternity Leave    1601 non-null   float64
#  3   Unpaid Maternity Leave  1601 non-null   float64
#  4   Paid Paternity Leave    1601 non-null   float64
#  5   Unpaid Paternity Leave  1601 non-null   int64
#  6   Paid Parental Leave     1601 non-null   float64
#  7   Unpaid Parental Leave   1601 non-null   float64
#  8   Total Parental Leave    1601 non-null   float64
#  9   Total Maternity Leave   1601 non-null   float64
#  10  Total Paternity Leave   1601 non-null   float64
#  11  Maternity VS Paternity  1601 non-null   bool
# dtypes: bool(1), float64(8), int64(1), object(2)
# memory usage: 139.3+ KB

# %% [markdown]
# # **Checking the null values**

# %%
a.isna().sum()
# Out:
# Company                   0
# Industry                  3
# Paid Maternity Leave      0
# Unpaid Maternity Leave    0
# Paid Paternity Leave      0
# Unpaid Paternity Leave    0
# Paid Parental Leave       0
# Unpaid Parental Leave     0
# Total Parental Leave      0
# Total Maternity Leave     0
# Total Paternity Leave     0
# Maternity VS Paternity    0
# dtype: int64

# %% [markdown]
# # **Getting the DataFrame of the null values**

# %%
print(df[df['Industry'].isnull()])
# Out:
#                      Company Industry  Paid Maternity Leave  \
# 1023                    ASML      NaN                  52.0
# 1024  INK Communications Co.      NaN                  10.0
# 1025                    Rokt      NaN                  15.0
#
#       Unpaid Maternity Leave  Paid Paternity Leave  Unpaid Paternity Leave  \
# 1023                    40.0                   0.0                       0
# 1024                     2.0                   0.0                       0
# 1025                     0.0                   0.0                       0
#
#       Paid Parental Leave  Unpaid Parental Leave   Total Parental Leave  \
# 1023                 52.0                    40.0                  92.0
# 1024                 10.0                     2.0                  12.0
# 1025                 15.0                     0.0                  15.0
#
#       Total Maternity Leave  Total Paternity Leave  Maternity VS Paternity
# ...

# %%
print(a.isnull().any())
# Out:
# Company                   False
# Industry                   True
# Paid Maternity Leave      False
# Unpaid Maternity Leave    False
# Paid Paternity Leave      False
# Unpaid Paternity Leave    False
# Paid Parental Leave       False
# Unpaid Parental Leave     False
# Total Parental Leave      False
# Total Maternity Leave     False
# Total Paternity Leave     False
# Maternity VS Paternity    False
# dtype: bool

# %% [markdown]
# # ***Fetching the null values using iloc operator***

# %%
a.iloc[[1023,1024,1025],[1]]
# Out:
#      Industry
# 1023      NaN
# 1024      NaN
# 1025      NaN

# %% [markdown]
# # **Fetching the null values using loc operator**

# %%
a.loc[[1023,1024,1025]]
# Out:
#                      Company Industry  Paid Maternity Leave  \
# 1023                    ASML      NaN                  52.0
# 1024  INK Communications Co.      NaN                  10.0
# 1025                    Rokt      NaN                  15.0
#
#       Unpaid Maternity Leave  Paid Paternity Leave  Unpaid Paternity Leave  \
# 1023                    40.0                   0.0                       0
# 1024                     2.0                   0.0                       0
# 1025                     0.0                   0.0                       0
#
#       Paid Parental Leave  Unpaid Parental Leave   Total Parental Leave  \
# 1023                 52.0                    40.0                  92.0
# 1024                 10.0                     2.0                  12.0
# 1025                 15.0                     0.0                  15.0
#
#       Total Maternity Leave  Total Paternity Leave  Maternity VS Paternity
# ...

# %% [markdown]
# ## **Which companies offer the most paid parental leave weeks?**

# %%
#importing matplotlib library
import matplotlib.pyplot as plt

# %%
df=pd.DataFrame(a)

# %%
df1 = df.iloc[:,[0,6]]
df1
# Out:
#                         Company  Paid Parental Leave
# 0                       Epsilon                 12.0
# 1       The Walt Disney Company                  9.5
# 2               Guild Education                 22.0
# 3                        WeWork                 30.0
# 4                  Randstad USA                  5.0
# ...                         ...                  ...
# 1596                       Xero                  6.0
# 1597         Fedex Supply Chain                  2.0
# 1598         Schneider National                  0.0
# 1599                  HD Supply                 14.0
# 1600  Merrimac Industrial Sales                  0.0
#
# [1601 rows x 2 columns]

# %%
df1.sort_values(by=["Paid Parental Leave"],ascending=False)
# Out:
#                          Company  Paid Parental Leave
# 47                Grant Thornton                102.0
# 148                    LAC-Group                 67.5
# 129              Flatiron Health                 60.0
# 207   Hewlett Packard Enterprise                 52.0
# 1431                 JHC Systems                 52.0
# ...                          ...                  ...
# 1219                      Uniqlo                  0.0
# 986                  Mayer Brown                  0.0
# 1229                 Industrious                  0.0
# 1235         Clean Harbors, Inc.                  0.0
# 1600   Merrimac Industrial Sales                  0.0
#
# [1601 rows x 2 columns]

# %% [markdown]
# ## **Is maternity leave typically longer than paternity leave?**

# %% [markdown]
# **Total Maternity Leave = Paid Maternity Leave + Unpaid Maternity Leave
# Total Paternity Leave = Paid Paternity Leave + Unpaid Paternity Leave**

# %%
df1 = df.iloc[:,[9,10,11]]
df1
# Out:
#       Total Maternity Leave  Total Paternity Leave  Maternity VS Paternity
# 0                      12.0                   12.0                   False
# 1                       9.0                    8.5                    True
# 2                      14.0                   12.0                    True
# 3                      16.0                   20.0                   False
# 4                      12.0                    0.0                    True
# ...                     ...                    ...                     ...
# 1596                    6.0                    0.0                    True
# 1597                    2.0                    0.0                    True
# 1598                    0.0                    0.0                   False
# 1599                   14.0                    0.0                    True
# 1600                    0.0                    0.0                   False
#
# [1601 rows x 3 columns]

# %%
df['Total Maternity Leave'].sum()
# Out:
# 27369.0

# %%
df['Total Paternity Leave'].sum()
# Out:
# 2614.0

# %%
#Maternity Leave is more than the Paternity Leave
df1.plot(subplots=True)
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# ## **What is the distribution of parental leave weeks offered?**

# %%
df1 = df.iloc[:,[0,8]]
df1
# Out:
#                         Company  Total Parental Leave
# 0                       Epsilon                  24.0
# 1       The Walt Disney Company                  17.5
# 2               Guild Education                  26.0
# 3                        WeWork                  36.0
# 4                  Randstad USA                  12.0
# ...                         ...                   ...
# 1596                       Xero                   6.0
# 1597         Fedex Supply Chain                   2.0
# 1598         Schneider National                   0.0
# 1599                  HD Supply                  14.0
# 1600  Merrimac Industrial Sales                   0.0
#
# [1601 rows x 2 columns]

# %%
df1.plot(kind="scatter", x= "Company", y="Total Parental Leave")
# Out:
# <Axes: xlabel='Company', ylabel='Total Parental Leave'>

# %% [markdown]
# ## **Are there noticeable differences between industries?**

# %%
df1 = df.iloc[:,[1,9,10]]
df1
# Out:
#                                        Industry  Total Maternity Leave  \
# 0                                   Advertising                   12.0
# 1                          Arts & Entertainment                    9.0
# 2                      Business Services: Other                   14.0
# 3                      Business Services: Other                   16.0
# 4     Business Services: Staffing & Outsourcing                   12.0
# ...                                         ...                    ...
# 1596                       Technology: Software                    6.0
# 1597        Transportation: Freight & Logistics                    2.0
# 1598        Transportation: Freight & Logistics                    0.0
# 1599                                  Wholesale                   14.0
# 1600                                  Wholesale                    0.0
#
#       Total Paternity Leave
# 0                      12.0
# 1                       8.5
# ...

# %%
df1.plot(figsize=(12,5))
# Out:
# <Axes: >
